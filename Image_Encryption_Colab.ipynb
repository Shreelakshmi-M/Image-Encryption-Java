# %% [markdown]
# # Basic Image Encryption Using Pixel-Level RGB Transformation in Java
#
# This notebook demonstrates a basic image transformation technique implemented in Java. RGB pixel values are modified using a user-defined key between 0 and 255. Python is used in Google Colab to upload, display, and compare the images, while the actual pixel transformation is performed by the Java program.

# %% [markdown]
# ## Step 1: Project Overview
#
# The project reads an input image, processes every pixel, extracts the ARGB components, applies modular arithmetic to the RGB values using the selected key, and saves the transformed image.

# %% [markdown]
# ## Step 2: Upload the Input Image
#
# Upload an image and save it as `input.png` so that the Java program can read it.

# %%
from google.colab import files
uploaded = files.upload()

# Rename the uploaded image to input.png if needed
import os
if 'input.png' not in uploaded:
    first_file = next(iter(uploaded))
    os.rename(first_file, 'input.png')
print('Input image is ready.')

# %% [markdown]
# ## Step 3: Display the Original Image

# %%
from PIL import Image
import matplotlib.pyplot as plt

original = Image.open('input.png')
plt.figure(figsize=(8, 5))
plt.imshow(original)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 4: Java Encryption Program
#
# The Java program processes every pixel. The Red, Green, and Blue components are transformed using the following formulas:
#
# `R' = (R + Key) mod 256`
# `G' = (G + Key) mod 256`
# `B' = (B + Key) mod 256`
#
# The Alpha channel is preserved while the RGB values are transformed.

# %%
# %%writefile ImageEncoder.java
# import java.awt.image.BufferedImage;
# import java.io.File;
# import javax.imageio.ImageIO;
#
# public class ImageEncoder {
#
#     public static void main(String[] args) {
#
#         try {
#             // Get encryption key from command-line argument
#             int key = Integer.parseInt(args[0]);
#
#             // Check whether the key is within the valid range
#             if (key < 0 || key > 255) {
#                 System.out.println("Invalid key! Enter a value between 0 and 255.");
#                 return;
#             }
#
#             // Read the input image
#             File inputFile = new File("input.png");
#
#             if (!inputFile.exists()) {
#                 System.out.println("Input image not found!");
#                 return;
#             }
#
#             BufferedImage image = ImageIO.read(inputFile);
#
#             int width = image.getWidth();
#             int height = image.getHeight();
#
#             // Process every pixel
#             for (int y = 0; y < height; y++) {
#                 for (int x = 0; x < width; x++) {
#
#                     int pixel = image.getRGB(x, y);
#
#                     // Extract ARGB components
#                     int alpha = (pixel >> 24) & 0xff;
#                     int red = (pixel >> 16) & 0xff;
#                     int green = (pixel >> 8) & 0xff;
#                     int blue = pixel & 0xff;
#
#                     // Transform RGB values using the encryption key
#                     red = (red + key) % 256;
#                     green = (green + key) % 256;
#                     blue = (blue + key) % 256;
#
#                     // Reconstruct the pixel
#                     int newPixel =
#                             (alpha << 24) |
#                             (red << 16) |
#                             (green << 8) |
#                             blue;
#
#                     image.setRGB(x, y, newPixel);
#                 }
#             }
#
#             // Save the encrypted image
#             File outputFile = new File("encoded_image.png");
#             ImageIO.write(image, "png", outputFile);
#
#             System.out.println("Image encrypted successfully!");
#             System.out.println("Encryption Key: " + key);
#             System.out.println("Output File: encoded_image.png");
#
#         } catch (NumberFormatException e) {
#             System.out.println("Invalid input! Please enter a number between 0 and 255.");
#
#         } catch (Exception e) {
#             System.out.println("Error: " + e.getMessage());
#         }
#     }
# }

# %% [markdown]
# ## Example Pixel Calculation
#
# Suppose one pixel has the following RGB values and the encryption key is 30:
#
# ```text
# R = 200
# G = 100
# B = 50
# Key = 30
# ```
#
# Applying the transformation:
#
# ```text
# R' = (200 + 30) mod 256 = 230
# G' = (100 + 30) mod 256 = 130
# B' = (50 + 30) mod 256 = 80
# ```
#
# Therefore, the original pixel `RGB(200, 100, 50)` becomes `RGB(230, 130, 80)`.
#
# The modulo 256 operation keeps each RGB component within the valid range of 0 to 255.

# %% [markdown]
# ## Step 5: Compile the Java Program
#
# The Java source code is compiled before execution.

# %%
# !javac ImageEncoder.java

# %% [markdown]
# ## Step 6: Enter Encryption Key
#
# The user can enter an encryption key between 0 and 255. The selected key is used to transform the RGB values of every pixel.

# %%
key = int(input('Enter encryption key (0-255): '))

if key < 0 or key > 255:
    print('Invalid key! Please enter a value between 0 and 255.')
else:
    print('Encryption key accepted:', key)

# %% [markdown]
# ## Step 7: Run the Java Encryption Program
#
# The key entered in the Colab notebook is passed to the Java program as a command-line argument. Python is only used here to execute the Java program.

# %%
import subprocess

if 0 <= key <= 255:
    result = subprocess.run(
        ['java', 'ImageEncoder', str(key)],
        capture_output=True,
        text=True
    )
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

# %% [markdown]
# ## Step 8: Display the Encrypted Image

# %%
from IPython.display import display
output_image = Image.open('encoded_image.png')
display(output_image)

# %% [markdown]
# ## Step 9: Original vs Encrypted Image
#
# The images are compared side by side. The image dimensions remain unchanged.

# %%
original = Image.open('input.png')
encrypted = Image.open('encoded_image.png')

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(original)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(encrypted)
plt.title(f'Encrypted Image - Key {key}')
plt.axis('off')
plt.show()

# %% [markdown]
# ## How the Pixel Transformation Works
#
# For each pixel, Alpha, Red, Green and Blue are extracted. The key is added to each RGB component and the result is taken modulo 256. The Alpha component is preserved.

# %% [markdown]
# ## Step 10: Test with a Different Key
#
# Run the input and encryption cells again with another key to observe a different result.

# %% [markdown]
# ## Special Test: Encryption Key = 0
#
# With key 0, each RGB value remains unchanged because `(value + 0) mod 256 = value`.

# %%
key = 0
result = subprocess.run(['java', 'ImageEncoder', str(key)], capture_output=True, text=True)
print(result.stdout)

# %% [markdown]
# ## Results
#
# The program transforms the RGB values of every pixel and generates the output image. Different keys produce different transformed pixel values while the image dimensions remain unchanged.

# %% [markdown]
# ## Technologies Used
#
# - **Java** – pixel-level RGB transformation
# - **Python / Google Colab** – image upload, display, and program execution
# - **BufferedImage and ImageIO** – image reading, pixel processing, and PNG output

# %% [markdown]
# # Conclusion
#
# The project demonstrates image processing, pixel-level RGB manipulation, modular arithmetic, and basic encryption concepts using Java. The Java program performs the actual RGB transformation, while Python in Google Colab is used for image upload, display, and execution support. This technique is intended for educational purposes and is not designed to provide high-security real-world image encryption.
